# %% [markdown]
# # Koneoppiminen: Osa 3: Naiivi Bayes-luokittelija

# %%
# Kirjoita tähän tietosi!
student_name = 'Marjo Nopola'
student_id = 'AA9074'

# %% [markdown]
# ## Tehtävä 1
# ### Aihe: Artificial Characters Data Set
#
# 4 pistettä
#
# 1. Tutustu *Wine Data Set* -aineistoon osoitteessa https://archive.ics.uci.edu/ml/datasets/Wine .
#
# 2. Lataa aineisto ja aseta sarakkeiden nimet.
#
# 3. Jaa aineisto koulutus- ja testausaineistoon käyttäen `scikit-learn`-kirjaston [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)-funktiota.
#
# 4. Normalisoi sarakkeet välille 0...1 `scikit-learn`-kirjaston `preprocessing`-moduulin [minmax_scale](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.minmax_scale.html#sklearn.preprocessing.minmax_scale)-funktiolla.
#
# - Tallenna koulutusaineisto ja sen luokkamuuttuja muuttujiin `X_train`, `y_train`,
# - ja toisaalta testausaineiston `X_test`, `y_test`.
#
# Aseta testausjoukon kooksi 33% ja satunnaisuuden siemeneksi `1900`.
#
# Vinkki: älä skaalaa luokkamuuttujaa.
#
# Vinkki: muista että luokkamuuttuja ei mene `X`-muuttujiin.

# %%
# Kirjoita toteutuksesi tähän soluun. 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import minmax_scale

df = pd.read_csv("wine.data", sep=',')

df.columns=["Class", "Alcohol", "Malic acid", "Ash", "Alcalinity of ash", "Magnesium", 
            "Total phenols", "Flavanoids", "Nonflavanoid phenols",
           "Proanthocyanins", "Color intensity", "Hue", "OD280/OD315 of diluted wines",
           "Proline"]

X = df.drop('Class', axis=1)
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1900)

X_train = minmax_scale(X_train, feature_range=(0, 1))  # 0-1 scaling
X_test = minmax_scale(X_test, feature_range=(0, 1))  # 0-1 scaling
X_train = pd.DataFrame(X_train, columns = X.columns)
X_test = pd.DataFrame(X_test, columns = X.columns)

# %%
# Tehtävän vastaukset. Huom! Älä muokkaa tätä solua, vaan aja se, kun olet suorittanut tehtävän. 
# Tallenna vastauksesi X_train- X_test-muuttujiin.
print(f'X_train columns: {X_train.columns}')
print(f'X_train: {X_train}')
print(f'X_test: {X_test}')
# Out:
# X_train columns: Index(['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
#        'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline'],
#       dtype='object')
# X_train:       Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0    0.112903    0.317227  0.566845           0.484536   0.282609
# 1    0.766129    0.871849  0.465241           0.484536   0.108696
# 2    0.478495    0.298319  0.556150           0.690722   0.304348
# 3    0.373656    0.743697  0.732620           0.819588   0.347826
# 4    0.575269    0.357143  0.540107           0.484536   0.543478
# ..        ...         ...       ...                ...        ...
# 113  0.615591    0.493697  0.545455           0.561856   0.239130
# 114  0.825269    0.237395  0.556150           0.422680   0.358696
# 115  0.709677    0.075630  0.299465           0.381443   0.260870
# 116  0.279570    0.266807  0.433155           0.536082   0.163043
# 117  0.879032    0.216387  0.727273           0.484536   0.543478
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.662069    0.516878              0.358491         0.446203
# 1         0.000000    0.000000              0.509434         0.082278
# 2         0.058621    0.158228              0.264151         0.129747
# 3         0.420690    0.377637              0.566038         0.408228
# 4         0.231034    0.071730              0.754717         0.329114
# ..             ...         ...                   ...              ...
# 113       0.327586    0.088608              0.603774         0.262658
# 114       0.610345    0.544304              0.358491         0.620253
# 115       0.386207    0.305907              0.358491         0.098101
# 116       0.558621    0.487342              0.452830         0.294304
# 117       0.627586    0.590717              0.377358         0.490506
#
#      Color intensity       Hue  OD280/OD315 of diluted wines   Proline
# 0           0.150849  0.260163                      0.776557  0.241007
# 1           0.315684  0.081301                      0.021978  0.089928
# 2           0.395604  0.146341                      0.032967  0.194245
# 3           0.033966  0.357724                      0.677656  0.053957
# 4           0.755245  0.097561                      0.128205  0.395683
# ..               ...       ...                           ...       ...
# 113         0.667333  0.056911                      0.128205  0.258993
# 114         0.445554  0.479675                      0.542125  0.553957
# 115         0.205794  0.609756                      0.435897  0.244604
# 116         0.101898  0.308943                      0.736264  0.063309
# 117         0.445554  0.479675                      0.505495  0.712230
#
# [118 rows x 13 columns]
# X_test:      Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0   0.347953    0.339921  0.323232           0.393939   0.250000
# 1   0.280702    0.077075  0.282828           0.424242   0.125000
# 2   0.479532    0.203557  0.222222           0.303030   0.482143
# 3   0.172515    0.035573  0.121212           0.424242   0.107143
# 4   0.257310    0.171937  0.333333           0.509091   0.410714
# 5   0.230994    0.452569  0.444444           0.424242   0.285714
# 6   0.868421    0.223320  0.505051           0.000000   0.392857
# 7   0.614035    0.209486  0.777778           0.424242   0.535714
# 8   0.716374    0.120553  0.393939           0.242424   0.321429
# 9   0.295322    0.171937  0.313131           0.636364   0.500000
# 10  0.269006    0.071146  0.404040           0.242424   0.375000
# 11  0.423977    0.120553  0.444444           0.363636   0.750000
# 12  0.681287    0.183794  0.373737           0.266667   0.678571
# 13  0.479532    1.000000  0.252525           0.575758   0.107143
# 14  0.412281    0.519763  0.424242           0.454545   0.142857
# 15  0.327485    0.942688  0.767677           0.787879   0.285714
# 16  0.868421    0.563241  0.404040           0.242424   0.392857
# 17  0.652047    0.466403  0.686869           0.193939   0.642857
# 18  0.634503    0.181818  0.484848           0.430303   0.464286
# 19  0.581871    0.626482  0.606061           0.666667   0.392857
# 20  0.453216    0.535573  0.474747           0.393939   0.464286
# 21  0.795322    0.664032  0.868687           0.757576   0.285714
# 22  0.444444    0.604743  0.777778           0.400000   0.392857
# 23  0.692982    0.399209  0.424242           0.606061   0.178571
# 24  0.119883    0.193676  0.000000           0.454545   0.107143
# 25  0.608187    0.563241  0.313131           0.454545   0.142857
# 26  0.000000    0.000000  0.626263           0.545455   0.142857
# 27  0.605263    0.211462  0.535354           0.515152   0.357143
# 28  0.479532    0.195652  0.161616           0.024242   0.214286
# 29  0.675439    0.136364  0.626263           0.284848   0.500000
# 30  0.116959    0.272727  0.868687           0.575758   0.964286
# 31  0.125731    0.424901  0.353535           0.363636   0.571429
# 32  0.426901    0.764822  0.606061           0.575758   0.107143
# 33  0.578947    0.203557  0.747475           0.248485   0.232143
# 34  0.684211    0.195652  0.535354           0.242424   0.160714
# 35  0.111111    0.274704  0.909091           1.000000   0.214286
# 36  0.479532    0.179842  0.676768           0.363636   0.321429
# 37  0.359649    0.122530  0.141414           0.290909   0.357143
# 38  1.000000    0.177866  0.292929           0.121212   0.303571
# 39  0.818713    0.652174  0.565657           0.418182   0.553571
# 40  0.269006    0.049407  0.070707           0.169697   1.000000
# 41  0.321637    0.098814  0.373737           0.333333   0.089286
# 42  0.687135    0.156126  0.828283           0.454545   0.928571
# 43  0.728070    0.185771  0.242424           0.242424   0.375000
# 44  0.856725    0.185771  0.828283           0.787879   0.321429
# 45  0.397661    0.531621  0.101010           0.242424   0.000000
# 46  0.678363    0.150198  0.828283           0.636364   0.375000
# 47  0.821637    0.642292  0.636364           0.072727   0.857143
# 48  0.514620    0.879447  0.444444           0.606061   0.232143
# 49  0.608187    0.181818  0.363636           0.727273   0.125000
# 50  0.821637    0.189723  0.424242           0.260606   0.678571
# 51  0.421053    0.500000  0.707071           0.606061   0.464286
# 52  0.716374    0.152174  0.797980           0.787879   0.107143
# 53  0.649123    0.211462  0.828283           0.315152   0.571429
# 54  0.570175    0.359684  0.474747           0.484848   0.160714
# 55  0.535088    0.365613  1.000000           0.545455   0.678571
# 56  0.429825    0.444664  0.525253           0.484848   0.428571
# 57  0.552632    0.193676  0.262626           0.303030   0.250000
# 58  0.172515    0.531621  0.121212           0.424242   0.125000
#
#     Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0        0.216667    0.056426              1.000000         0.207843
# 1        1.000000    0.821317              0.102041         0.572549
# 2        0.791667    0.789969              0.285714         0.635294
# 3        0.550000    0.557994              0.326531         0.400000
# 4        0.000000    0.169279              0.469388         0.411765
# 5        0.062500    0.003135              0.530612         0.125490
# 6        0.916667    0.990596              0.306122         1.000000
# 7        0.520833    0.642633              0.306122         0.443137
# 8        0.783333    0.836991              0.163265         0.564706
# 9        0.375000    0.504702              0.408163         0.470588
# 10       0.395833    0.191223              1.000000         0.000000
# 11       0.170833    0.241379              0.142857         0.207843
# 12       0.625000    0.758621              0.142857         0.474510
# 13       0.633333    0.680251              0.326531         0.627451
# 14       0.158333    0.056426              0.530612         0.219608
# 15       0.287500    0.037618              1.000000         0.270588
# 16       0.895833    0.843260              0.265306         0.698039
# 17       0.666667    0.799373              0.061224         0.490196
# 18       0.733333    0.849530              0.163265         0.603922
# 19       0.291667    0.084639              0.591837         0.392157
# 20       0.120833    0.068966              0.530612         0.207843
# 21       0.395833    0.087774              0.857143         0.368627
# 22       0.545833    0.605016              0.224490         0.615686
# 23       0.104167    0.062696              0.551020         0.243137
# 24       0.583333    0.363636              0.469388         0.396078
# 25       0.216667    0.000000              0.897959         0.184314
# 26       0.575000    0.479624              0.571429         0.403922
# 27       0.666667    0.783699              0.244898         0.568627
# 28       0.675000    0.874608              0.061224         0.980392
# 29       0.958333    1.000000              0.102041         0.639216
# 30       0.208333    0.159875              0.000000         0.450980
# 31       0.258333    0.263323              0.591837         0.211765
# 32       0.250000    0.053292              0.673469         0.176471
# 33       0.729167    0.771160              0.408163         0.407843
# 34       0.625000    0.714734              0.306122         0.549020
# 35       0.429167    0.551724              0.897959         0.529412
# 36       0.562500    0.611285              0.306122         0.403922
# 37       0.383333    0.291536              0.795918         0.082353
# 38       0.708333    0.783699              0.306122         0.615686
# 39       0.729167    0.680251              0.326531         0.329412
# 40       0.333333    0.429467              0.428571         0.921569
# 41       0.375000    0.031348              0.938776         0.329412
# 42       0.770833    0.708464              0.734694         0.368627
# 43       0.833333    0.912226              0.142857         0.678431
# 44       0.708333    0.260188              0.795918         0.898039
# 45       0.220833    0.241379              0.591837         0.164706
# 46       0.791667    0.868339              0.306122         0.772549
# 47       0.791667    0.802508              0.122449         0.654902
# 48       0.266667    0.047022              0.959184         0.447059
# 49       0.325000    0.426332              0.265306         0.243137
# 50       0.875000    0.789969              0.244898         0.635294
# 51       0.229167    0.037618              0.938776         0.215686
# 52       0.770833    0.746082              0.142857         0.572549
# 53       0.729167    0.761755              0.326531         0.411765
# 54       0.125000    0.006270              0.469388         0.090196
# 55       0.708333    0.692790              0.510204         0.552941
# 56       0.083333    0.231975              0.204082         0.164706
# 57       0.541667    0.536050              0.265306         0.368627
# 58       0.375000    0.363636              0.469388         0.572549
#
#     Color intensity       Hue  OD280/OD315 of diluted wines   Proline
# 0          0.496587  0.226190                      0.128319  0.328605
# 1          0.270478  0.809524                      0.699115  0.111899
# 2          0.320819  0.404762                      0.911504  0.478329
# 3          0.104096  1.000000                      0.809735  0.000000
# 4          0.151024  0.435714                      0.234513  0.466509
# 5          0.360068  0.142857                      0.238938  0.182821
# 6          0.530717  0.785714                      0.756637  1.000000
# 7          0.249147  0.666667                      0.699115  0.643814
# 8          0.506826  0.559524                      1.000000  0.604413
# 9          0.066553  0.619048                      0.738938  0.052797
# 10         0.169795  0.845238                      0.168142  0.316785
# 11         0.240614  0.261905                      0.000000  0.277384
# 12         0.389932  0.452381                      0.845133  0.616233
# 13         0.112628  0.226190                      0.800885  0.080378
# 14         0.766212  0.214286                      0.203540  0.320725
# 15         0.317406  0.333333                      0.176991  0.186761
# 16         0.308874  0.595238                      0.951327  0.620173
# 17         0.325939  0.500000                      0.915929  0.446809
# 18         0.479522  0.654762                      0.703540  0.974783
# 19         0.513652  0.190476                      0.119469  0.371946
# 20         0.341297  0.166667                      0.203540  0.312845
# 21         0.675768  0.083333                      0.137168  0.222222
# 22         0.274744  0.583333                      0.986726  0.387707
# 23         0.708191  0.190476                      0.172566  0.265563
# 24         0.066553  0.476190                      0.508850  0.107959
# 25         0.377133  0.321429                      0.234513  0.237983
# 26         0.153584  0.666667                      0.451327  0.122931
# 27         0.325939  0.595238                      0.964602  0.505910
# 28         0.505119  0.690476                      0.716814  0.687155
# 29         0.470990  0.416667                      0.699115  0.793538
# 30         0.104096  0.488095                      0.429204  0.273444
# 31         0.116894  0.500000                      0.544248  0.174941
# 32         0.543515  0.000000                      0.252212  0.273444
# 33         0.300341  0.452381                      0.853982  0.722616
# 34         0.368601  0.726190                      0.712389  0.821119
# 35         0.146758  0.511905                      0.508850  0.148148
# 36         0.253413  0.690476                      0.539823  0.651694
# 37         0.381399  0.523810                      0.132743  0.135540
# 38         0.334471  0.642857                      0.690265  0.604413
# 39         0.337884  0.392857                      0.902655  0.631994
# 40         0.180887  0.619048                      0.451327  0.371946
# 41         0.355802  0.250000                      0.097345  0.293144
# 42         0.351536  0.845238                      0.756637  0.754137
# 43         0.411263  0.440476                      0.902655  0.557132
# 44         1.000000  0.035714                      0.296460  0.301024
# 45         0.180887  0.190476                      0.367257  0.074074
# 46         0.377133  0.773810                      0.628319  0.793538
# 47         0.325939  0.416667                      0.991150  0.379827
# 48         0.564846  0.071429                      0.084071  0.352246
# 49         0.209898  0.523810                      0.659292  0.152876
# 50         0.435154  0.476190                      0.893805  0.545311
# 51         0.366894  0.392857                      0.362832  0.230102
# 52         0.179181  0.976190                      0.827434  0.104019
# 53         0.513652  0.880952                      0.703540  0.813239
# 54         0.368601  0.190476                      0.522124  0.395587
# 55         0.259386  0.595238                      0.725664  0.360126
# 56         0.351536  0.238095                      0.057522  0.198582
# 57         0.227816  0.571429                      0.654867  0.793538
# 58         0.000000  0.464286                      0.778761  0.225374

# %% [markdown]
# ## Tehtävä 2
# ### Aihe: Gaussian Naive Bayes
#
# 2 pistettä
#
# Käytä `scikit-learn`-kirjastosta löytyvää *Gaussian Naive Bayes* -menetelmää aineiston luokittelemiseksi.
#
# Ennnusta testiaineiston luokka. Tallenna ennusteet `y_pred`-muuttujaan.

# %%
# Kirjoita toteutuksesi tähän soluun. 
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %%
# Tehtävän vastaukset. Huom! Älä muokkaa tätä solua, vaan aja se, kun olet suorittanut tehtävän. 
# Tallenna ennusteen tulokset y_pred-muuttujaan.
print(f'{len(y_pred)}')
# Out:
# 59

# %% [markdown]
# ## Tehtävä 3
# ### Aihe: Tarkkuuden mittaaminen
#
# 4 pistettä
#
# Hyödynnä `scikit-learn`-kirjaston `metrics`-moduulin funktioita ja laske luokittelutuloksesi **tarkkuus** sekä **sekaannusmatriisi**. Tallenna tarkkuus muuttujaan `acc` ja sekaannusmatriisi muuttujaan `cm`.
#
# Vinkki: onnistumista voit mitata ainoastaa testiaineiston osalta!

# %%
# Kirjoita toteutuksesi tähän soluun.
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

acc = accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test, y_pred)

# %%
# Tehtävän vastaukset. Huom! Älä muokkaa tätä solua, vaan aja se, kun olet suorittanut tehtävän. 
# Tallenna vastauksesi acc- ja cm-muuttujiin.
print(f'Accuracy: {acc}')
print(f'Confusion matrix:\n {cm}')
# Out:
# Accuracy: 0.9830508474576272
# Confusion matrix:
#  [[25  0  0]
#  [ 0 17  0]
#  [ 0  1 16]]
